# %%
import train
import torch

# %%
qm, model = train.run(img=256, batch=100, epochs=3, data='data.yaml', cfg='yolov5s.yaml')
# Out:
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, img=256, batch=100
# github:
# YOLOv5 🚀 v6.0-0-g956be8e torch 1.9.0 CPU
#
# ...

# %%
print(qm)
# Out:
# Model(
#   (model): Sequential(
#     (0): Conv(
#       (convb): QuantizedConv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), scale=0.038001175969839096, zero_point=122, padding=(2, 2))
#       (act): SiLU()
#     )
#     (1): Conv(
#       (convb): QuantizedConv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), scale=0.06784284859895706, zero_point=126, padding=(1, 1))
#       (act): SiLU()
#     )
#     (2): C3(
#       (cv1): Conv(
#         (convb): QuantizedConv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.08700858056545258, zero_point=106)
#         (act): SiLU()
#       )
#       (cv2): Conv(
#         (convb): QuantizedConv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), scale=0.0847206711769104, zero_point=121)
#         (act): SiLU()
#       )
#       (cv3): Conv(
#         (convb): QuantizedConv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), scale=0.11366870999336243, zero_point=135)
#         (act): SiLU()
#       )
#       (m): Sequential(
#         (0): Bottleneck(
# ...

# %%
for x in dir(qm):
    print(x)
# Out:
# T_destination
# __annotations__
# __call__
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattr__
# __getattribute__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setstate__
# __sizeof__
# __slotnames__
# __str__
# __subclasshook__
# __weakref__
# _apply
# _backward_hooks
# _buffers
# _call_impl
# _clip_augmented
# _descale_pred
# _forward_augment
# _forward_hooks
# _forward_once
# _forward_pre_hooks
# _get_backward_hooks
# _get_name
# _initialize_biases
# _is_full_backward_hook
# _load_from_state_dict
# _load_state_dict_pre_hooks
# _maybe_warn_non_full_backward_hook
# _modules
# _named_members
# _non_persistent_buffers_set
# _parameters
# _print_biases
# _profile_one_layer
# _register_load_state_dict_pre_hook
# _register_state_dict_hook
# _replicate_for_data_parallel
# _save_to_state_dict
# _slow_forward
# _state_dict_hooks
# ...

# %%
for x in qm.state_dict():
    print(qm.state_dict()[x])
# Out:
# tensor([[[[ 0.00000,  0.01170, -0.01794, -0.01638, -0.00858,  0.00624],
#           [-0.00078,  0.01716, -0.00156,  0.00546, -0.00702, -0.00468],
#           [-0.02106, -0.01482, -0.00936,  0.00078,  0.00858,  0.01326],
#           [-0.01482, -0.00936,  0.00780,  0.01794, -0.00468,  0.01638],
#           [-0.00390,  0.00234,  0.02028, -0.02028, -0.01404, -0.00546],
#           [-0.00858,  0.01872, -0.01404, -0.01014, -0.01560, -0.02028]],
#
#          [[-0.01248,  0.01872,  0.01014,  0.01092,  0.00078, -0.01092],
#           [ 0.00390, -0.02028, -0.01560, -0.01170,  0.01404,  0.01326],
#           [-0.00936, -0.00078,  0.01404,  0.02184,  0.00858,  0.00312],
#           [ 0.01482, -0.01326,  0.00390, -0.01716, -0.01560, -0.01170],
#           [ 0.01014,  0.00858, -0.01326,  0.00702,  0.01170, -0.00312],
#           [ 0.00078,  0.00546,  0.01326,  0.02106, -0.01716, -0.00780]],
#
#          [[ 0.00858,  0.01794,  0.01950,  0.01950,  0.00468, -0.01872],
# ...

# %%
torch.save(qm.state_dict(),"test/test.pt")

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[[[-0.00072,  0.05161, -0.07922, -0.07080, -0.03705,  0.02580],
#            [-0.00191,  0.07629, -0.00854,  0.02547, -0.02908, -0.01892],
#            [-0.09192, -0.06372, -0.03967,  0.00356,  0.03806,  0.05774],
#            [-0.06525, -0.04190,  0.03494,  0.07990, -0.01981,  0.07202],
#            [-0.01551,  0.01019,  0.08716, -0.08929, -0.06058, -0.02437],
#            [-0.03751,  0.08313, -0.06238, -0.04428, -0.06720, -0.09015]],
#
#           [[-0.05618,  0.08270,  0.04294,  0.04663,  0.00506, -0.04935],
#            [ 0.01628, -0.08984, -0.06952, -0.04962,  0.06070,  0.05643],
#            [-0.04266, -0.00347,  0.06155,  0.09564,  0.03818,  0.01300],
#            [ 0.06451, -0.05667,  0.01793, -0.07458, -0.06671, -0.04971],
#            [ 0.04355,  0.03870, -0.05701,  0.02907,  0.05283, -0.01215],
#            [ 0.00367,  0.02229,  0.05969,  0.09241, -0.07416, -0.03528]],
#
# ...
